# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kritikseth/fruit-and-vegetable-image-recognition")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/lilgreg/.cache/kagglehub/datasets/kritikseth/fruit-and-vegetable-image-recognition/versions/8

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Explore the dataset structure
dataset_path = path
print(f"Dataset path: {dataset_path}")
print("\nFolder structure:")
for root, dirs, files in os.walk(dataset_path):
    level = root.replace(dataset_path, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    if level < 2:  # Only show first 2 levels
        subindent = ' ' * 2 * (level + 1)
        for file in files[:2]:  # Show first 2 files
            print(f'{subindent}{file}')
# Out:
# Dataset path: /home/lilgreg/.cache/kagglehub/datasets/kritikseth/fruit-and-vegetable-image-recognition/versions/8
#
# Folder structure:
# 8/
#   validation/
#     ginger/
#     turnip/
#     spinach/
#     orange/
#     pineapple/
#     eggplant/
#     pear/
#     sweetcorn/
#     tomato/
#     sweetpotato/
#     grapes/
#     lemon/
#     kiwi/
#     banana/
#     paprika/
#     apple/
#     cucumber/
#     garlic/
#     cabbage/
#     chilli pepper/
#     lettuce/
#     onion/
#     soy beans/
#     cauliflower/
#     watermelon/
#     potato/
#     raddish/
#     capsicum/
#     corn/
#     peas/
#     mango/
#     beetroot/
#     pomegranate/
#     bell pepper/
#     jalepeno/
#     carrot/
#   test/
#     ginger/
#     turnip/
#     spinach/
#     orange/
#     pineapple/
#     eggplant/
#     pear/
#     sweetcorn/
#     tomato/
#     sweetpotato/
#     grapes/
#     lemon/
#     kiwi/
#     banana/
#     paprika/
#     apple/
#     cucumber/
#     garlic/
#     cabbage/
#     chilli pepper/
#     lettuce/
#     onion/
#     soy beans/
#     cauliflower/
#     watermelon/
#     potato/
#     raddish/
#     capsicum/
#     corn/
#     peas/
#     mango/
#     beetroot/
#     pomegranate/
#     bell pepper/
#     jalepeno/
#     carrot/
#   train/
#     ginger/
#     turnip/
#     spinach/
#     orange/
#     pineapple/
#     eggplant/
#     pear/
#     sweetcorn/
#     tomato/
#     sweetpotato/
#     grapes/
#     lemon/
#     kiwi/
#     banana/
#     paprika/
#     apple/
#     cucumber/
#     garlic/
#     cabbage/
#     chilli pepper/
#     lettuce/
#     onion/
#     soy beans/
#     cauliflower/
#     watermelon/
#     potato/
#     raddish/
#     capsicum/
#     corn/
#     peas/
#     mango/
#     beetroot/
#     pomegranate/
#     bell pepper/
#     jalepeno/
#     carrot/

# %%
# Define data transformations
train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(20),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])

val_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])

# Load datasets from folder structure
train_dataset = datasets.ImageFolder(os.path.join(dataset_path, 'train'), transform=train_transforms)
test_dataset = datasets.ImageFolder(os.path.join(dataset_path, 'test'), transform=val_transforms)

# Create data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# Display dataset information
print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of test samples: {len(test_dataset)}")
print(f"Number of classes: {len(train_dataset.classes)}")
print(f"Classes: {train_dataset.classes}")
# Out:
# Number of training samples: 3115
# Number of test samples: 359
# Number of classes: 36
# Classes: ['apple', 'banana', 'beetroot', 'bell pepper', 'cabbage', 'capsicum', 'carrot', 'cauliflower', 'chilli pepper', 'corn', 'cucumber', 'eggplant', 'garlic', 'ginger', 'grapes', 'jalepeno', 'kiwi', 'lemon', 'lettuce', 'mango', 'onion', 'orange', 'paprika', 'pear', 'peas', 'pineapple', 'pomegranate', 'potato', 'raddish', 'soy beans', 'spinach', 'sweetcorn', 'sweetpotato', 'tomato', 'turnip', 'watermelon']

# %%
# Load pre-trained ResNet18 model with transfer learning
model = models.resnet18(pretrained=True)

# Freeze early layers (keep learned features)
for param in model.parameters():
    param.requires_grad = False

# Replace the final classification layer
num_classes = len(train_dataset.classes)
model.fc = nn.Linear(model.fc.in_features, num_classes)

# Unfreeze the last layer and fc layer for fine-tuning
for param in model.fc.parameters():
    param.requires_grad = True

model = model.to(device)
print(f"Model loaded and moved to {device}")
print(f"Final layer updated to output {num_classes} classes")

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

print("Loss function: CrossEntropyLoss")
print("Optimizer: Adam (lr=0.001)")
# Out:
# /home/lilgreg/anaconda3/lib/python3.13/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/lilgreg/anaconda3/lib/python3.13/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Model loaded and moved to cuda
# Final layer updated to output 36 classes
# Loss function: CrossEntropyLoss
# Optimizer: Adam (lr=0.001)

# %%
# Training function
def train_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    progress_bar = tqdm(dataloader, desc="Training")
    for images, labels in progress_bar:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
        progress_bar.set_postfix({'loss': running_loss / total, 'acc': 100 * correct / total})
    
    epoch_loss = running_loss / len(dataloader)
    epoch_acc = 100 * correct / total
    return epoch_loss, epoch_acc

# Validation function
def validate(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    epoch_loss = running_loss / len(dataloader)
    epoch_acc = 100 * correct / total
    return epoch_loss, epoch_acc, np.array(all_preds), np.array(all_labels)

print("Training and validation functions defined!")
# Out:
# Training and validation functions defined!

# %%
# Train the model
num_epochs = 15
best_acc = 0
history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    print("-" * 50)
    
    # Train
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)
    
    # Validate
    val_loss, val_acc, _, _ = validate(model, test_loader, criterion, device)
    
    # Store history
    history['train_loss'].append(train_loss)
    history['train_acc'].append(train_acc)
    history['val_loss'].append(val_loss)
    history['val_acc'].append(val_acc)
    
    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
    print(f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%")
    
    # Save best model
    if val_acc > best_acc:
        best_acc = val_acc
        torch.save(model.state_dict(), 'best_fruit_veg_model.pth')
        print("✓ Best model saved!")
    
    # Adjust learning rate
    scheduler.step(val_loss)

print("\nTraining complete!")
# Out:
# Epoch 1/15
# --------------------------------------------------
# Training:   8%|▊         | 8/98 [00:07<01:20,  1.11it/s, loss=0.113, acc=5.08]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 11
#       8 print("-" * 50)
#      10 # Train
# ---> 11 train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)
#      13 # Validate
#      14 val_loss, val_acc, _, _ = validate(model, test_loader, criterion, device)
#
# Cell In[10], line 9, in train_epoch(model, dataloader, criterion, optimizer, device)
#       6 total = 0
#       8 progress_bar = tqdm(dataloader, desc="Training")
# ----> 9 for images, labels in progress_bar:
#      10     images, labels = images.to(device), labels.to(device)
#      12     optimizer.zero_grad()
#
# File ~/anaconda3/lib/python3.13/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/lib/python3.13/site-packages/torch/utils/data/dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File ~/anaconda3/lib/python3.13/site-packages/torch/utils/data/dataloader.py:1524, in _MultiProcessingDataLoaderIter._next_data(self)
#    1520 if self._shutdown or self._tasks_outstanding <= 0:
#    1521     raise AssertionError(
#    1522         "Invalid iterator state: shutdown or no outstanding tasks when fetching next data"
#    1523     )
# -> 1524 idx, data = self._get_data()
#    1525 self._tasks_outstanding -= 1
#    1526 if self._dataset_kind == _DatasetKind.Iterable:
#    1527     # Check for _IterableDatasetStopIteration
#
# File ~/anaconda3/lib/python3.13/site-packages/torch/utils/data/dataloader.py:1483, in _MultiProcessingDataLoaderIter._get_data(self)
#    1479     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1480     # need to call `.task_done()` because we don't use `.join()`.
#    1481 else:
#    1482     while True:
# -> 1483         success, data = self._try_get_data()
#    1484         if success:
#    1485             return data
#
# File ~/anaconda3/lib/python3.13/site-packages/torch/utils/data/dataloader.py:1310, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1297 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1298     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1299     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1307     # Returns a 2-tuple:
#    1308     #   (bool: whether successfully get data, any: data if successful else None)
#    1309     try:
# -> 1310         data = self._data_queue.get(timeout=timeout)
#    1311         return (True, data)
#    1312     except Exception as e:
#    1313         # At timeout and error, we manually check whether any worker has
#    1314         # failed. Note that this is the only mechanism for Windows to detect
#    1315         # worker failures.
#
# File ~/anaconda3/lib/python3.13/multiprocessing/queues.py:111, in Queue.get(self, block, timeout)
#     109 if block:
#     110     timeout = deadline - time.monotonic()
# --> 111     if not self._poll(timeout):
#     112         raise Empty
#     113 elif not self._poll():
#
# File ~/anaconda3/lib/python3.13/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~/anaconda3/lib/python3.13/multiprocessing/connection.py:440, in Connection._poll(self, timeout)
#     439 def _poll(self, timeout):
# --> 440     r = wait([self], timeout)
#     441     return bool(r)
#
# File ~/anaconda3/lib/python3.13/multiprocessing/connection.py:1148, in wait(object_list, timeout)
#    1145     deadline = time.monotonic() + timeout
#    1147 while True:
# -> 1148     ready = selector.select(timeout)
#    1149     if ready:
#    1150         return [key.fileobj for (key, events) in ready]
#
# File ~/anaconda3/lib/python3.13/selectors.py:398, in _PollLikeSelector.select(self, timeout)
#     396 ready = []
#     397 try:
# --> 398     fd_event_list = self._selector.poll(timeout)
#     399 except InterruptedError:
#     400     return ready
#
# KeyboardInterrupt:

# %%
# Plot training history
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Loss plot
ax1.plot(history['train_loss'], label='Train Loss', marker='o')
ax1.plot(history['val_loss'], label='Val Loss', marker='s')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('Training and Validation Loss')
ax1.legend()
ax1.grid(True)

# Accuracy plot
ax2.plot(history['train_acc'], label='Train Accuracy', marker='o')
ax2.plot(history['val_acc'], label='Val Accuracy', marker='s')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('Training and Validation Accuracy')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

print(f"Best validation accuracy: {best_acc:.2f}%")
# Out:
# Best validation accuracy: 0.00%

# %%
# Final evaluation on test set
print("Final Model Evaluation")
print("=" * 50)

# Load best model
model.load_state_dict(torch.load('fruit_and_veg_model.pth'))

# Get predictions
_, _, all_preds, all_labels = validate(model, test_loader, criterion, device)

# Classification report
print("\nClassification Report:")
print(classification_report(all_labels, all_preds, target_names=train_dataset.classes))

# Confusion matrix visualization
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(12, 10))
plt.imshow(cm, cmap='Blues', interpolation='nearest')
plt.title('Confusion Matrix')
plt.colorbar()
plt.xticks(range(len(train_dataset.classes)), train_dataset.classes, rotation=45, ha='right')
plt.yticks(range(len(train_dataset.classes)), train_dataset.classes)
plt.tight_layout()
plt.show()
# Out:
# Final Model Evaluation
# ==================================================
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         apple       0.88      0.70      0.78        10
#        banana       1.00      0.78      0.88         9
#      beetroot       1.00      0.90      0.95        10
#   bell pepper       0.73      0.80      0.76        10
#       cabbage       1.00      1.00      1.00        10
#      capsicum       0.55      0.60      0.57        10
#        carrot       1.00      1.00      1.00        10
#   cauliflower       1.00      1.00      1.00        10
# chilli pepper       0.60      0.90      0.72        10
#          corn       1.00      0.60      0.75        10
#      cucumber       1.00      1.00      1.00        10
#      eggplant       1.00      1.00      1.00        10
#        garlic       0.91      1.00      0.95        10
#        ginger       1.00      1.00      1.00        10
#        grapes       1.00      1.00      1.00        10
#      jalepeno       0.69      0.90      0.78        10
#          kiwi       1.00      1.00      1.00        10
#         lemon       1.00      0.90      0.95        10
#       lettuce       1.00      0.90      0.95        10
#         mango       1.00      0.90      0.95        10
#         onion       1.00      1.00      1.00        10
#        orange       0.91      1.00      0.95        10
#       paprika       0.86      0.60      0.71        10
#          pear       1.00      1.00      1.00        10
#          peas       1.00      1.00      1.00        10
#     pineapple       1.00      1.00      1.00        10
#   pomegranate       1.00      1.00      1.00        10
#        potato       1.00      0.70      0.82        10
#       raddish       1.00      1.00      1.00        10
#     soy beans       1.00      1.00      1.00        10
#       spinach       0.91      1.00      0.95        10
#     sweetcorn       0.71      1.00      0.83        10
#   sweetpotato       0.90      0.90      0.90        10
#        tomato       0.82      0.90      0.86        10
#        turnip       1.00      1.00      1.00        10
#    watermelon       1.00      1.00      1.00        10
#
#      accuracy                           0.92       359
#     macro avg       0.93      0.92      0.92       359
#  weighted avg       0.93      0.92      0.92       359

# %%
# Function to make predictions on new images
def predict_image(image_path, model, class_names, device):
    """Predict the fruit/vegetable in a single image"""
    model.eval()
    
    # Load and transform image
    image = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                            std=[0.229, 0.224, 0.225])
    ])(Image.open(image_path).convert('RGB'))
    
    image = image.unsqueeze(0).to(device)
    
    with torch.no_grad():
        outputs = model(image)
        probabilities = torch.nn.functional.softmax(outputs, dim=1)
        top_pred = torch.argmax(probabilities, 1)
    
    predicted_class = class_names[top_pred.item()]
    confidence = probabilities[0][top_pred].item() * 100
    
    return predicted_class, confidence, probabilities[0].cpu().numpy()

# Example usage (uncomment if you have an image to test)
from PIL import Image
image_path = "/home/lilgreg/ML/Fruit_n_veg_classifier/cucumba.jpeg"
pred_class, confidence, _ = predict_image(image_path, model, train_dataset.classes, device)
print(f"Prediction: {pred_class} (Confidence: {confidence:.2f}%)")
# Out:
# Prediction: jalepeno (Confidence: 46.24%)

# %%
import torch
import cv2 as cv
import numpy
from PIL import Image
from torchvision import transforms

def predict_frame(frame, model, class_names, device):
    """Predict the fruit/vegetable in an OpenCV frame"""
    model.eval()
    
    # 1. Convert BGR (OpenCV) to RGB
    frame_rgb = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
    
    # 2. Convert NumPy array to PIL Image 
    # (This makes it compatible with your existing torchvision transforms)
    pil_image = Image.fromarray(frame_rgb)
    
    # 3. Apply your preprocessing pipeline
    preprocess = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
    
    image_tensor = preprocess(pil_image).unsqueeze(0).to(device)
    
    # 4. Inference
    with torch.no_grad():
        outputs = model(image_tensor)
        probabilities = torch.nn.functional.softmax(outputs, dim=1)
        top_pred = torch.argmax(probabilities, 1)
    
    predicted_class = class_names[top_pred.item()]
    confidence = probabilities[0][top_pred].item() * 100
    
    return predicted_class, confidence

# %%
 
##
# Opens a video capture device with a resolution of 800x600
# at 30 FPS.
##
def open_camera(cam_id = 0):
    cap = cv.VideoCapture(cam_id)
    cap.set(cv.CAP_PROP_FRAME_HEIGHT, 600)
    cap.set(cv.CAP_PROP_FRAME_WIDTH, 800)
    cap.set(cv.CAP_PROP_FPS, 30)
    return cap
 
##
# Gets a frame from an open video device, or returns None
# if the capture could not be made.
##
def get_frame(device):
    ret, img = device.read()
    if (ret == False): # failed to capture
        print("Failed to capture from camera. Check if it is connected and try again.")
        return None
    return img
 
##
# Closes all OpenCV windows and releases video capture device
# before exit.
##
def cleanup(cam_id = 0): 
    cv.destroyAllWindows()
    cv.VideoCapture(cam_id).release()
 
##
# Creates a new RGB image of the specified size, initially
# filled with black.
##
def new_rgb_image(width, height):
    image = numpy.zeros( (height, width, 3), numpy.uint8)
    return image

########### Main Program ###########

if __name__ == "__main__":
    # Camera ID to read video from (numbered from 0)
    camera_id = 0
    dev = open_camera(camera_id) # open the camera as a video capture device
    # Prepare an incremental filename counter by scanning existing captures

    while True:
        img_orig = get_frame(dev) # Get a frame from the camera
        if img_orig is not None: # if we did get an image
            cv.imshow("video", img_orig) # display the image in a window named "video"
            
        else: # if we failed to capture (camera disconnected?), then quit
            break

        pred_class, confidence= predict_frame(img_orig, model, train_dataset.classes, device)
        print(f"Prediction: {pred_class} (Confidence: {confidence:.2f}%)")

        key = cv.waitKey(1) # wait for 1 ms for a key press
        if key == 27: # if the key was ESC, then quit   
            break
 
    cleanup(camera_id) # close video device and windows before we exit
# Out:
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
#
# QObject::moveToThread: Current thread (0x4cf0d220) is not the object's thread (0x4d2578c0).
# Cannot move to target thread (0x4cf0d220)
# Prediction: raddish (Confidence: 15.17%)
# Prediction: mango (Confidence: 14.96%)
# Prediction: mango (Confidence: 15.60%)
# Prediction: raddish (Confidence: 14.19%)
# Prediction: raddish (Confidence: 16.01%)
# Prediction: mango (Confidence: 15.26%)
# Prediction: mango (Confidence: 16.33%)
# Prediction: mango (Confidence: 15.80%)
# Prediction: raddish (Confidence: 15.45%)
# Prediction: raddish (Confidence: 15.10%)
# Prediction: raddish (Confidence: 13.58%)
# Prediction: mango (Confidence: 12.93%)
# Prediction: mango (Confidence: 13.98%)
# Prediction: mango (Confidence: 12.99%)
# Prediction: mango (Confidence: 12.55%)
# Prediction: mango (Confidence: 13.14%)
# Prediction: mango (Confidence: 11.35%)
# Prediction: raddish (Confidence: 13.41%)
# Prediction: mango (Confidence: 12.54%)
# Prediction: mango (Confidence: 12.41%)
# Prediction: mango (Confidence: 14.56%)
# Prediction: raddish (Confidence: 13.34%)
# Prediction: mango (Confidence: 13.61%)
# Prediction: mango (Confidence: 13.06%)
# Prediction: mango (Confidence: 11.36%)
# Prediction: raddish (Confidence: 12.11%)
# Prediction: raddish (Confidence: 12.77%)
# Prediction: raddish (Confidence: 15.74%)
# Prediction: raddish (Confidence: 14.17%)
# Prediction: raddish (Confidence: 16.58%)
# Prediction: raddish (Confidence: 15.68%)
# Prediction: raddish (Confidence: 15.14%)
# Prediction: raddish (Confidence: 15.89%)
# Prediction: raddish (Confidence: 16.86%)
# Prediction: raddish (Confidence: 14.23%)
# Prediction: raddish (Confidence: 15.67%)
# Prediction: raddish (Confidence: 15.19%)
# Prediction: raddish (Confidence: 16.01%)
# Prediction: raddish (Confidence: 16.90%)
# Prediction: raddish (Confidence: 15.73%)
# Prediction: raddish (Confidence: 15.04%)
# Prediction: raddish (Confidence: 14.90%)
# Prediction: raddish (Confidence: 17.37%)
# Prediction: raddish (Confidence: 14.21%)
# Prediction: raddish (Confidence: 16.59%)
# Prediction: raddish (Confidence: 15.48%)
# Prediction: raddish (Confidence: 16.27%)
# Prediction: raddish (Confidence: 16.81%)
# Prediction: raddish (Confidence: 19.28%)
# Prediction: raddish (Confidence: 18.24%)
# Prediction: raddish (Confidence: 17.63%)
# Prediction: raddish (Confidence: 18.45%)
# Prediction: raddish (Confidence: 16.43%)
# Prediction: raddish (Confidence: 15.72%)
# Prediction: raddish (Confidence: 17.02%)
# Prediction: raddish (Confidence: 17.76%)
# Prediction: raddish (Confidence: 19.98%)
# Prediction: raddish (Confidence: 15.87%)
# Prediction: raddish (Confidence: 16.10%)
# Prediction: raddish (Confidence: 16.53%)
# Prediction: raddish (Confidence: 16.28%)
# Prediction: raddish (Confidence: 16.44%)
# Prediction: raddish (Confidence: 17.40%)
# Prediction: raddish (Confidence: 16.30%)
# Prediction: raddish (Confidence: 14.86%)
# Prediction: raddish (Confidence: 15.99%)
# Prediction: raddish (Confidence: 16.74%)
# Prediction: raddish (Confidence: 13.98%)
# Prediction: raddish (Confidence: 13.39%)
# Prediction: raddish (Confidence: 14.03%)
# Prediction: raddish (Confidence: 14.15%)
# Prediction: raddish (Confidence: 16.66%)
# Prediction: raddish (Confidence: 11.98%)
# Prediction: raddish (Confidence: 13.71%)
# Prediction: raddish (Confidence: 17.38%)
# Prediction: raddish (Confidence: 14.47%)
# Prediction: raddish (Confidence: 15.43%)
# Prediction: raddish (Confidence: 14.82%)
# Prediction: raddish (Confidence: 16.65%)
# Prediction: raddish (Confidence: 15.02%)
# Prediction: raddish (Confidence: 12.84%)
# Prediction: raddish (Confidence: 15.71%)
# Prediction: raddish (Confidence: 15.35%)
# Prediction: raddish (Confidence: 13.72%)
# Prediction: raddish (Confidence: 14.67%)
# Prediction: raddish (Confidence: 13.05%)
# Prediction: raddish (Confidence: 14.82%)
# Prediction: mango (Confidence: 13.11%)
# Prediction: raddish (Confidence: 12.08%)
# Prediction: raddish (Confidence: 12.99%)
# Prediction: mango (Confidence: 12.38%)
# Prediction: mango (Confidence: 13.20%)
# Prediction: raddish (Confidence: 11.70%)
# Prediction: raddish (Confidence: 13.55%)
# Prediction: raddish (Confidence: 14.77%)
# Prediction: raddish (Confidence: 12.04%)
# Prediction: raddish (Confidence: 14.04%)
# Prediction: raddish (Confidence: 11.43%)
# Prediction: apple (Confidence: 13.12%)
# Prediction: raddish (Confidence: 12.07%)
# Prediction: apple (Confidence: 13.49%)
# Prediction: apple (Confidence: 13.52%)
# Prediction: apple (Confidence: 11.41%)
# Prediction: apple (Confidence: 11.30%)
# Prediction: apple (Confidence: 13.63%)
# Prediction: apple (Confidence: 13.55%)
# Prediction: apple (Confidence: 12.93%)
# Prediction: apple (Confidence: 15.95%)
# Prediction: apple (Confidence: 13.79%)
# Prediction: apple (Confidence: 15.03%)
# Prediction: apple (Confidence: 14.48%)
# Prediction: orange (Confidence: 15.39%)
# Prediction: orange (Confidence: 16.34%)
# Prediction: pomegranate (Confidence: 20.73%)
# Prediction: apple (Confidence: 13.08%)
# Prediction: mango (Confidence: 18.35%)
# Prediction: lemon (Confidence: 12.13%)
# Prediction: lemon (Confidence: 11.67%)
# Prediction: paprika (Confidence: 18.22%)
# Prediction: paprika (Confidence: 17.30%)
# Prediction: paprika (Confidence: 18.97%)
# Prediction: paprika (Confidence: 14.62%)
# Prediction: lemon (Confidence: 16.26%)
# Prediction: paprika (Confidence: 21.03%)
# Prediction: paprika (Confidence: 25.58%)
# Prediction: paprika (Confidence: 41.96%)
# Prediction: paprika (Confidence: 38.56%)
# Prediction: paprika (Confidence: 35.64%)
# Prediction: paprika (Confidence: 29.93%)
# Prediction: lemon (Confidence: 30.39%)
# Prediction: lemon (Confidence: 28.13%)
# Prediction: soy beans (Confidence: 20.01%)
# Prediction: lemon (Confidence: 21.90%)
# Prediction: lemon (Confidence: 21.47%)
# Prediction: lemon (Confidence: 26.31%)
# Prediction: lemon (Confidence: 28.40%)
# Prediction: lemon (Confidence: 17.20%)
# Prediction: lemon (Confidence: 26.17%)
# Prediction: orange (Confidence: 22.27%)
# Prediction: orange (Confidence: 19.88%)
# Prediction: lemon (Confidence: 19.26%)
# Prediction: lemon (Confidence: 20.04%)
# Prediction: lemon (Confidence: 20.09%)
# Prediction: lemon (Confidence: 19.67%)
# Prediction: onion (Confidence: 18.15%)
# Prediction: lemon (Confidence: 16.85%)
# Prediction: lemon (Confidence: 16.47%)
# Prediction: lemon (Confidence: 28.15%)
# Prediction: lemon (Confidence: 26.72%)
# Prediction: lemon (Confidence: 23.57%)
# Prediction: paprika (Confidence: 19.34%)
# Prediction: onion (Confidence: 28.26%)
# Prediction: onion (Confidence: 23.65%)
# Prediction: lemon (Confidence: 24.47%)
# Prediction: paprika (Confidence: 25.25%)
# Prediction: paprika (Confidence: 21.22%)
# Prediction: paprika (Confidence: 26.14%)
# Prediction: lemon (Confidence: 26.25%)
# Prediction: lemon (Confidence: 28.85%)
# Prediction: paprika (Confidence: 18.86%)
# Prediction: onion (Confidence: 28.31%)
# Prediction: onion (Confidence: 26.21%)
# Prediction: paprika (Confidence: 24.11%)
# Prediction: lemon (Confidence: 23.65%)
# Prediction: paprika (Confidence: 28.17%)
# Prediction: eggplant (Confidence: 24.36%)
# Prediction: eggplant (Confidence: 19.69%)
# Prediction: onion (Confidence: 25.88%)
# Prediction: eggplant (Confidence: 21.31%)
# Prediction: paprika (Confidence: 24.78%)
# Prediction: paprika (Confidence: 41.00%)
# Prediction: paprika (Confidence: 26.02%)
# Prediction: paprika (Confidence: 25.25%)
# Prediction: paprika (Confidence: 30.09%)
# Prediction: paprika (Confidence: 29.25%)
# Prediction: paprika (Confidence: 22.91%)
# Prediction: paprika (Confidence: 28.26%)
# Prediction: onion (Confidence: 25.82%)
# Prediction: orange (Confidence: 20.83%)
# Prediction: lemon (Confidence: 18.62%)
# Prediction: paprika (Confidence: 25.90%)
# Prediction: paprika (Confidence: 22.45%)
# Prediction: onion (Confidence: 29.03%)
# Prediction: paprika (Confidence: 22.73%)
# Prediction: paprika (Confidence: 27.19%)
# Prediction: lemon (Confidence: 21.56%)
# Prediction: lemon (Confidence: 19.03%)
# Prediction: paprika (Confidence: 19.99%)
# Prediction: lemon (Confidence: 21.93%)
# Prediction: lemon (Confidence: 24.74%)
# Prediction: lemon (Confidence: 21.88%)
# Prediction: paprika (Confidence: 14.70%)
# Prediction: lemon (Confidence: 21.09%)
# Prediction: lemon (Confidence: 21.56%)
# Prediction: onion (Confidence: 18.18%)
# Prediction: lemon (Confidence: 17.09%)
# Prediction: lemon (Confidence: 20.68%)
# Prediction: lemon (Confidence: 18.61%)
# Prediction: lemon (Confidence: 15.31%)
# Prediction: lemon (Confidence: 20.85%)
# Prediction: paprika (Confidence: 17.59%)
# Prediction: lemon (Confidence: 18.02%)
# Prediction: lemon (Confidence: 21.37%)
# Prediction: onion (Confidence: 18.51%)
# Prediction: onion (Confidence: 19.64%)
# Prediction: onion (Confidence: 17.39%)
# Prediction: lemon (Confidence: 24.02%)
# Prediction: lemon (Confidence: 28.05%)
# Prediction: lemon (Confidence: 25.70%)
# Prediction: paprika (Confidence: 22.53%)
# Prediction: paprika (Confidence: 28.95%)
# Prediction: paprika (Confidence: 22.68%)
# Prediction: lemon (Confidence: 19.24%)
# Prediction: lemon (Confidence: 24.88%)
# Prediction: lemon (Confidence: 26.78%)
# Prediction: lemon (Confidence: 22.22%)
# Prediction: lemon (Confidence: 32.06%)
# Prediction: lemon (Confidence: 35.24%)
# Prediction: lemon (Confidence: 26.57%)
# Prediction: lemon (Confidence: 26.77%)
# Prediction: lemon (Confidence: 20.20%)
# Prediction: paprika (Confidence: 23.09%)
# Prediction: onion (Confidence: 18.85%)
# Prediction: lemon (Confidence: 21.99%)
# Prediction: lemon (Confidence: 39.03%)
# Prediction: lemon (Confidence: 33.77%)
# Prediction: lemon (Confidence: 35.33%)
# Prediction: lemon (Confidence: 41.02%)
# Prediction: lemon (Confidence: 30.03%)
# Prediction: lemon (Confidence: 34.28%)
# Prediction: lemon (Confidence: 29.88%)
# Prediction: lemon (Confidence: 50.31%)
# Prediction: lemon (Confidence: 37.54%)
# Prediction: lemon (Confidence: 40.07%)
# Prediction: lemon (Confidence: 43.96%)
# Prediction: lemon (Confidence: 39.38%)
# Prediction: lemon (Confidence: 28.18%)
# Prediction: onion (Confidence: 21.38%)
# Prediction: onion (Confidence: 21.99%)
# Prediction: onion (Confidence: 27.13%)
# Prediction: onion (Confidence: 31.64%)
# Prediction: onion (Confidence: 27.58%)
# Prediction: onion (Confidence: 29.02%)
# Prediction: lemon (Confidence: 30.60%)
# Prediction: onion (Confidence: 28.80%)
# Prediction: onion (Confidence: 33.52%)
# Prediction: onion (Confidence: 37.95%)
# Prediction: onion (Confidence: 38.16%)
# Prediction: onion (Confidence: 41.22%)
# Prediction: onion (Confidence: 21.40%)
# Prediction: lemon (Confidence: 29.35%)
# Prediction: onion (Confidence: 25.72%)
# Prediction: lemon (Confidence: 33.75%)
# Prediction: lemon (Confidence: 33.24%)
# Prediction: lemon (Confidence: 31.70%)
# Prediction: lemon (Confidence: 22.10%)
# Prediction: onion (Confidence: 21.96%)
# Prediction: onion (Confidence: 25.02%)
# Prediction: onion (Confidence: 36.93%)
# Prediction: onion (Confidence: 25.53%)
# Prediction: onion (Confidence: 19.05%)
# Prediction: onion (Confidence: 16.77%)
# Prediction: onion (Confidence: 14.10%)
# Prediction: onion (Confidence: 19.26%)
# Prediction: onion (Confidence: 16.81%)
# Prediction: onion (Confidence: 36.20%)
# Prediction: onion (Confidence: 21.90%)
# Prediction: onion (Confidence: 20.32%)
# Prediction: onion (Confidence: 15.07%)
# Prediction: lemon (Confidence: 14.74%)
# Prediction: lemon (Confidence: 13.54%)
# Prediction: onion (Confidence: 17.02%)
# Prediction: onion (Confidence: 32.36%)
# Prediction: lemon (Confidence: 25.21%)
# Prediction: lemon (Confidence: 21.71%)
# Prediction: onion (Confidence: 22.02%)
# Prediction: onion (Confidence: 24.17%)
# Prediction: onion (Confidence: 28.21%)
# Prediction: onion (Confidence: 18.74%)
# Prediction: soy beans (Confidence: 16.82%)
# Prediction: onion (Confidence: 18.09%)
# Prediction: soy beans (Confidence: 17.51%)
# Prediction: soy beans (Confidence: 16.68%)
# Prediction: onion (Confidence: 20.96%)
# Prediction: soy beans (Confidence: 17.09%)
# Prediction: onion (Confidence: 20.51%)
# Prediction: onion (Confidence: 21.51%)
# Prediction: onion (Confidence: 25.15%)
# Prediction: lemon (Confidence: 21.01%)
# Prediction: onion (Confidence: 27.76%)
# Prediction: onion (Confidence: 28.36%)
# Prediction: onion (Confidence: 33.61%)
# Prediction: onion (Confidence: 22.50%)
# Prediction: onion (Confidence: 25.05%)
# Prediction: onion (Confidence: 16.02%)
# Prediction: onion (Confidence: 16.54%)
# Prediction: lemon (Confidence: 21.54%)
# Prediction: onion (Confidence: 24.23%)
# Prediction: onion (Confidence: 25.00%)
# Prediction: onion (Confidence: 24.94%)
# Prediction: onion (Confidence: 25.23%)
# Prediction: onion (Confidence: 30.48%)
# Prediction: onion (Confidence: 32.03%)
# Prediction: onion (Confidence: 34.61%)
# Prediction: onion (Confidence: 34.43%)
# Prediction: onion (Confidence: 36.30%)
# Prediction: onion (Confidence: 26.84%)
# Prediction: onion (Confidence: 29.57%)
# Prediction: onion (Confidence: 16.68%)
# Prediction: lemon (Confidence: 23.56%)
# Prediction: onion (Confidence: 19.96%)
# Prediction: lemon (Confidence: 19.21%)
# Prediction: onion (Confidence: 16.11%)
# Prediction: onion (Confidence: 20.45%)
# Prediction: onion (Confidence: 21.90%)
# Prediction: onion (Confidence: 27.51%)
# Prediction: onion (Confidence: 19.69%)
# Prediction: lemon (Confidence: 16.89%)
# Prediction: onion (Confidence: 22.24%)
# Prediction: onion (Confidence: 26.23%)
# Prediction: onion (Confidence: 22.80%)
# Prediction: onion (Confidence: 21.74%)
# Prediction: onion (Confidence: 21.19%)
# Prediction: onion (Confidence: 36.43%)
# Prediction: onion (Confidence: 20.88%)
# Prediction: onion (Confidence: 19.13%)
# Prediction: onion (Confidence: 21.19%)
# Prediction: onion (Confidence: 17.33%)
# Prediction: orange (Confidence: 14.41%)
# Prediction: orange (Confidence: 14.01%)
# Prediction: orange (Confidence: 12.57%)
# Prediction: pomegranate (Confidence: 10.10%)
# Prediction: pomegranate (Confidence: 11.15%)
# Prediction: raddish (Confidence: 11.33%)
# Prediction: apple (Confidence: 11.51%)
# Prediction: raddish (Confidence: 12.31%)
# Prediction: raddish (Confidence: 11.67%)
# Prediction: raddish (Confidence: 10.99%)
# Prediction: apple (Confidence: 9.24%)
# Prediction: bell pepper (Confidence: 9.71%)
# Prediction: garlic (Confidence: 9.09%)
# Prediction: apple (Confidence: 13.74%)
# Prediction: apple (Confidence: 8.08%)
# Prediction: garlic (Confidence: 11.32%)
# Prediction: garlic (Confidence: 15.57%)
# Prediction: garlic (Confidence: 18.41%)
# Prediction: garlic (Confidence: 14.58%)
# Prediction: garlic (Confidence: 14.31%)
# Prediction: garlic (Confidence: 11.50%)
# Prediction: garlic (Confidence: 14.07%)
# Prediction: garlic (Confidence: 9.75%)
# Prediction: raddish (Confidence: 12.24%)
# Prediction: raddish (Confidence: 13.64%)
# Prediction: raddish (Confidence: 19.17%)
# Prediction: raddish (Confidence: 22.52%)
# Prediction: raddish (Confidence: 21.09%)
# Prediction: raddish (Confidence: 29.59%)
# Prediction: raddish (Confidence: 23.88%)
# Prediction: raddish (Confidence: 23.53%)
# Prediction: raddish (Confidence: 16.55%)
# Prediction: raddish (Confidence: 15.15%)
# Prediction: raddish (Confidence: 19.43%)
# Prediction: raddish (Confidence: 20.80%)
# Prediction: raddish (Confidence: 19.32%)
# Prediction: raddish (Confidence: 19.25%)
# Prediction: raddish (Confidence: 20.17%)
# Prediction: raddish (Confidence: 20.49%)
# Prediction: raddish (Confidence: 19.64%)
# Prediction: raddish (Confidence: 19.53%)
# Prediction: raddish (Confidence: 19.86%)
# Prediction: raddish (Confidence: 17.20%)
# Prediction: raddish (Confidence: 19.24%)
# Prediction: raddish (Confidence: 18.73%)
# Prediction: raddish (Confidence: 18.92%)
# Prediction: raddish (Confidence: 16.82%)
# Prediction: raddish (Confidence: 16.03%)
# Prediction: raddish (Confidence: 16.40%)
# Prediction: raddish (Confidence: 21.06%)
# Prediction: raddish (Confidence: 17.21%)
# Prediction: raddish (Confidence: 16.20%)
# Prediction: raddish (Confidence: 15.94%)
# [ WARN:0@278.812] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [video4linux2,v4l2 @ 0x49b9f180] ioctl(VIDIOC_G_INPUT): Inappropriate ioctl for device
# [ERROR:0@278.813] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
